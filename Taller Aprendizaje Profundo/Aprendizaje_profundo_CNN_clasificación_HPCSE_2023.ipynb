# %% [markdown]
# # Notebook clasificación de imágenes usando Tensorflow.Keras aplicación de aprendizaje profundo (Redes neuronales convolucionales)
# **Palabras clave:
# Análisis de Imágenes,
# Unidad de procesamiento gráfico (GPU, por sus siglas en inglés),
# aprendizaje profundo (Red neuronal convolucional),
# característica operativa del receptor (curva ROC, por sus siglas en inglés),
# Accuracy**

# %%
import pandas as pd #Biblioteca para importar datos.
import numpy as np #Biblioteca para crear arreglos.
from matplotlib import pyplot as plt #Biblioteca para plotear.
from IPython.display import Image #Biblioteca para mostrar imágenes.
import tensorflow as tf #Biblioteca para crear modelos de máquinas de aprendizaje.
import keras # Biblioteca Keras es una API de aprendizaje profundo escrita en Python, que se ejecuta sobre la plataforma de aprendizaje automático TensorFlow
from tensorflow.keras import layers # Biblioteca para crear capas, las cuales son componentes básicos de las redes neuronales en Keras
from tensorflow.keras.models import Sequential #Biblioteca para crear modelos secuenciales.
from keras.layers import Conv2D, MaxPool2D, Activation #Biblioteca para importar capas convolucionales, max pooling y funciones de activación
from keras.layers import Dropout, Dense, Flatten, BatchNormalization #Biblioteca para importar Dropout(establece aleatoriamente las unidades de entrada), Flatten (tranformación de mapa de características a un vector columna), y  BatchNormalization La normalización por lotes aplica una transformación entre 0-1
#from google.colab import drive #Biblioteca para importar datos desde google drive.
from keras.layers import Dense #Biblioteca para crear las capas de las redes neuronales (Una capa consta de una función de cálculo de tensor de entrada y tensor de salida).
from keras.optimizers import Adam #Biblioteca del optimizador que implementa el algoritmo Adam.
from tensorflow.keras.applications import ResNet152V2  # Biblioteca para usar modelos entrenados
from keras.layers import Dense, GlobalAvgPool2D as GAP, Dropout  # Biblioteca para denifir modelos de capas
from keras.callbacks import ModelCheckpoint, EarlyStopping  # Biblioteca para objeto que puede realizar acciones en varias etapas de entrenamiento
from keras.models import load_model # Biblioteca para cargar modelos de entrenamiento .h5

#Autores:
##Martínez Felipe Miguel de Jesús

#El siguiente conjunto de datos se obtuvo de la referencia [1], acontinuación se presentan su uso, el cual es únicamente para fines didácticos


#Consideraciones:
#Si se desea implementar una tarjeta gráfica de vídeo para acelerar el entrenamiento de la red neuronal, se recomienda ver el siguiente link para ver versiones de software [3]

# %% [markdown]
# **Impresión de la versión de TensorFlow e implementación de GPU (considerar installar controladores nvidia y revisar versión de TensorFlow)**
#
# **En caso de no ocupar GPU entonces: [Ir a Descarga de archivos](#descarga)**

# %%
print(tf.__version__)
# Out:
# 2.10.0

# %%
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0
# 2023-08-15 11:55:36.866330: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-15 11:55:37.587009: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.601817: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.601902: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.866709: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.866813: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.866874: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.866933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /device:GPU:0 with 6110 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-08-15 11:55:37.867468: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.867539: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.867593: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.867657: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.867709: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.867748: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /device:GPU:0 with 6110 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
tf.test.is_built_with_cuda()
# Out:
# True

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs:", len(physical_devices))
# Out:
# Num GPUs: 1
# 2023-08-15 11:55:37.995709: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.995881: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:37.995956: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
# !nvidia-smi
# Out:
# Tue Aug 15 11:55:38 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3070        Off | 00000000:01:00.0 Off |                  N/A |
# |  0%   42C    P2              59W / 270W |    326MiB /  8192MiB |      3%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    913590      C   /usr/bin/python3                            320MiB |
# +---------------------------------------------------------------------------------------+

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Thu_Nov_18_09:45:30_PST_2021
# Cuda compilation tools, release 11.5, V11.5.119
# Build cuda_11.5.r11.5/compiler.30672275_0

# %% [markdown]
# **Obtención de las imágenes de rostro de animales [1], Dataset_Animals.zip?rlkey=zo9qhjm3yvopx7wdqmbui83xz&dl=0** <a id='descarga'></a>

# %%
# !wget https://www.dropbox.com/scl/fi/xgxt0a4dwuu57ttqhy7hn/Dataset_Animals.zip?rlkey=zo9qhjm3yvopx7wdqmbui83xz&dl=0 -O Dataset_Animals.zip

# %% [markdown]
# **Ahora se descromprime el archivo Dataset_Animals.zip?rlkey=zo9qhjm3yvopx7wdqmbui83xz en la ruta**

# %%
# !unzip Dataset_Animals.zip?rlkey=zo9qhjm3yvopx7wdqmbui83xz

# %% [markdown]
# **Se definen las carpetas que contienen las imágenes de entrenamiento y las imágenes de prueba**

# %%
train_dir = '/content/afhq/train/' # Datos de entrenamiento
test_dir = '/content/afhq/val/'  #Datos de Prueba

# %% [markdown]
# **Se establecen los parámetros de las imágenes**

# %%
batch_size = 64 # Inicialmente 64
img_height = 512
img_width = 512

# %% [markdown]
# **Con ayuda de la biblioteca tf.keras se realiza la adquisición de las imágenes que se encuentran en un directorio en específico**

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, #ruta de la carpeta con imágenes
    validation_split=0.3, #70% para el conjunto de entrenamiento y 30% para el conjunto de prueba
    subset='training', # categoría entrenamiento
    seed=123, # Semilla aleatoria opcional
    image_size=(img_height, img_width), #Tamaño de las imágenes
    batch_size=batch_size) #Tamaño de lote de datos, si no se específica entonces de determina 32
# Out:
# Found 14630 files belonging to 3 classes.
# Using 10241 files for training.
# 2023-08-15 11:55:38.900351: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:38.900527: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:38.900614: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:38.900747: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:38.900835: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-15 11:55:38.900902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6110 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_dir, #ruta de la carpeta con imágenes
  validation_split=0.3, #70% para el conjunto de entrenamiento y 30% para el conjunto de prueba
  subset="validation", # categoría validación (prueba)
  seed=123, #Semilla aleatoria opcional
  image_size=(img_height, img_width), #Tamaño de las imágenes
  batch_size=batch_size) #Tamaño de lote de datos, si no se específica entonces de determina 32
# Out:
# Found 1500 files belonging to 3 classes.
# Using 450 files for validation.

# %% [markdown]
# **Se imprimen las clases para clasificación**

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cat', 'dog', 'wild']

# %% [markdown]
# **Se plotea una muestra de 9 imágenes a clasificar**

# %%
plt.figure(figsize= (10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype('uint8'))
    plt.title(class_names[labels[i]])
    plt.axis('off')

# %%
#for image_batch, labels_batch in train_ds:
#  print(image_batch.shape)
#  print(labels_batch.shape)
#  break

# %% [markdown]
# **Para escalar una entrada en el rango [0, 255] para que esté en el rango [0, 1], pasaría scale=1./255**

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %% [markdown]
# **Corroboramos que los datos de entrenamiento esten normalizados**
#
# $\LARGE x_{escala} = \frac{x-x_{min}}{x_{max}-x_{min}}$

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
X_train, y_train = next(iter(normalized_ds))
first_image = X_train[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
normalized_test = test_ds.map(lambda x, y: (normalization_layer(x), y))
X_test, y_test = next(iter(normalized_test))
first_img = X_test[0]
print(np.min(first_img), np.max(first_img))
# Out:
# 0.0 1.0

# %% [markdown]
# **Haciendo uso de la biblioteca tf.keras.utils.to_categorical, asignamos los datos de entrenamiento y prueba para etiquetar cada valor en la clase correspondiente.**
#
# Nota: en este notebook tenemos 3 clases ['cat', 'dog', 'wild']

# %%
y_train = tf.keras.utils.to_categorical(y_train, 3)
y_test = tf.keras.utils.to_categorical(y_test, 3)

# %% [markdown]
# # Modelo 1
#
# **Se genera un modelo de red neuronal convolucional**
#
# **3 capas de convolución**
#
# **3 capas de Max pooling**
#
# **1 capa Flatten**
#
# **3 capas de Densas**
#
# **En cuanto al optimizador se ocupa el descenso por gradiente estocástico ADAM [2]**

# %%
model = Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(512, 512, 3)),
  tf.keras.layers.MaxPool2D((2,2)),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
  tf.keras.layers.MaxPool2D((2,2)),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
  tf.keras.layers.MaxPool2D((2,2)),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(units=128, activation="relu"),
  tf.keras.layers.Dense(units=64, activation="relu"),
  tf.keras.layers.Dense(units=3, activation="softmax")
])

#opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer='adam', loss = 'CategoricalCrossentropy',
                   metrics = ['accuracy']) #0.001-> Default, batch_size -> Default 32

# %%
#model.summary()

# %% [markdown]
# **Se imprime el modelo de la red neuronal convolucional**

# %%
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True) #pip install pydot

# %% [markdown]
# **El modelo de entramiento se realiza con un tamaño de muestra de 32 datos por default que conforman las características, con la finalidad de encontrar el mejor resultado (prueba y error).**
#
# **Se realiza un entrenamiento con 30 epocas a iterar.**

# %%
 history = model.fit(
    X_train, y_train, # Datos de entrenamiento
    epochs = 30, #Número de epocas
    validation_data=(X_test, y_test), #Se asigan los datos de validación
    verbose=1 #verbosidad. 0 = sin impresión, 1 = barra de progreso, 2 = una línea por época.
)
# Out:
# Epoch 1/30
# 2023-08-15 11:55:41.584091: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8202
# 2023-08-15 11:55:42.144273: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.48GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-08-15 11:55:42.144291: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.48GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-08-15 11:55:42.840872: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2/2 [==============================] - 3s 292ms/step - loss: 7.3336 - accuracy: 0.4219 - val_loss: 15.6681 - val_accuracy: 0.3594
# Epoch 2/30
# 2/2 [==============================] - 0s 199ms/step - loss: 11.1087 - accuracy: 0.3438 - val_loss: 1.6177 - val_accuracy: 0.3594
# Epoch 3/30
# 2/2 [==============================] - 0s 199ms/step - loss: 1.5075 - accuracy: 0.4375 - val_loss: 1.3357 - val_accuracy: 0.4375
# Epoch 4/30
# 2/2 [==============================] - 0s 198ms/step - loss: 1.1068 - accuracy: 0.5938 - val_loss: 1.0575 - val_accuracy: 0.4531
# Epoch 5/30
# 2/2 [==============================] - 0s 199ms/step - loss: 1.0175 - accuracy: 0.6406 - val_loss: 1.1150 - val_accuracy: 0.3594
# Epoch 6/30
# 2/2 [==============================] - 0s 199ms/step - loss: 0.9118 - accuracy: 0.5469 - val_loss: 1.0158 - val_accuracy: 0.5469
# Epoch 7/30
# 2/2 [==============================] - 0s 198ms/step - loss: 0.8326 - accuracy: 0.5625 - val_loss: 1.0269 - val_accuracy: 0.3906
# Epoch 8/30
# 2/2 [==============================] - 0s 198ms/step - loss: 0.7356 - accuracy: 0.6875 - val_loss: 1.0275 - val_accuracy: 0.4844
# Epoch 9/30
# 2/2 [==============================] - 0s 198ms/step - loss: 0.6382 - accuracy: 0.7188 - val_loss: 0.8524 - val_accuracy: 0.7031
# Epoch 10/30
# 2/2 [==============================] - 0s 197ms/step - loss: 0.4674 - accuracy: 0.8906 - val_loss: 0.8298 - val_accuracy: 0.6875
# Epoch 11/30
# 2/2 [==============================] - 0s 197ms/step - loss: 0.3873 - accuracy: 0.8906 - val_loss: 0.8477 - val_accuracy: 0.7031
# Epoch 12/30
# 2/2 [==============================] - 0s 198ms/step - loss: 0.3192 - accuracy: 0.9062 - val_loss: 0.7879 - val_accuracy: 0.6719
# Epoch 13/30
# 2/2 [==============================] - 0s 200ms/step - loss: 0.2114 - accuracy: 0.9531 - val_loss: 0.8129 - val_accuracy: 0.7344
# Epoch 14/30
# 2/2 [==============================] - 0s 198ms/step - loss: 0.1344 - accuracy: 0.9844 - val_loss: 0.8990 - val_accuracy: 0.6562
# Epoch 15/30
# 2/2 [==============================] - 0s 196ms/step - loss: 0.1071 - accuracy: 1.0000 - val_loss: 0.7013 - val_accuracy: 0.7969
# Epoch 16/30
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0670 - accuracy: 1.0000 - val_loss: 0.7368 - val_accuracy: 0.7969
# Epoch 17/30
# 2/2 [==============================] - 0s 199ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.8998 - val_accuracy: 0.6719
# Epoch 18/30
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.8356 - val_accuracy: 0.7500
# Epoch 19/30
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.8975 - val_accuracy: 0.7812
# Epoch 20/30
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.7699 - val_accuracy: 0.7969
# Epoch 21/30
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.9698 - val_accuracy: 0.6875
# Epoch 22/30
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 1.0150 - val_accuracy: 0.7031
# Epoch 23/30
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9517 - val_accuracy: 0.7812
# Epoch 24/30
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.0873 - val_accuracy: 0.7812
# Epoch 25/30
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.0716 - val_accuracy: 0.7969
# Epoch 26/30
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.9878 - val_accuracy: 0.8125
# Epoch 27/30
# 2/2 [==============================] - 0s 196ms/step - loss: 7.1537e-04 - accuracy: 1.0000 - val_loss: 0.9121 - val_accuracy: 0.8125
# Epoch 28/30
# 2/2 [==============================] - 0s 197ms/step - loss: 3.8111e-04 - accuracy: 1.0000 - val_loss: 0.9120 - val_accuracy: 0.8281
# Epoch 29/30
# 2/2 [==============================] - 0s 198ms/step - loss: 2.3068e-04 - accuracy: 1.0000 - val_loss: 0.9864 - val_accuracy: 0.7188
# Epoch 30/30
# 2/2 [==============================] - 0s 197ms/step - loss: 2.6296e-04 - accuracy: 1.0000 - val_loss: 1.0894 - val_accuracy: 0.7188

# %%
loss, accuracy = model.evaluate(X_train,y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test,y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Training Accuracy: 1.0000
# Testing Accuracy:  0.7188

# %%
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# # Modelo 2

# %%
model = Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(512, 512, 3)),
  tf.keras.layers.MaxPool2D((2,2)),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
  tf.keras.layers.MaxPool2D((2,2)),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
  tf.keras.layers.MaxPool2D((2,2)),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(units=128, activation="relu"),
  tf.keras.layers.Dense(units=64, activation="relu"),
  tf.keras.layers.Dense(units=3, activation="softmax")
])

opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss = 'CategoricalCrossentropy',
                   metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 512, 512, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 256, 256, 32)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 32)      9248
#
#  max_pooling2d_4 (MaxPooling  (None, 128, 128, 32)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 64)      18496
#
#  max_pooling2d_5 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 262144)            0
#
#  dense_3 (Dense)             (None, 128)               33554560
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 33,591,651
# Trainable params: 33,591,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
 history = model.fit(
    X_train, y_train,
    epochs = 15,
    validation_data=(X_test, y_test),
    verbose=1,
    batch_size=16
)
# Out:
# Epoch 1/15
# 4/4 [==============================] - 1s 135ms/step - loss: 1.3576 - accuracy: 0.2969 - val_loss: 1.1360 - val_accuracy: 0.3594
# Epoch 2/15
# 4/4 [==============================] - 0s 88ms/step - loss: 1.0755 - accuracy: 0.3750 - val_loss: 1.0660 - val_accuracy: 0.3594
# Epoch 3/15
# 4/4 [==============================] - 0s 88ms/step - loss: 0.9982 - accuracy: 0.5156 - val_loss: 1.0855 - val_accuracy: 0.3750
# Epoch 4/15
# 4/4 [==============================] - 0s 88ms/step - loss: 0.9841 - accuracy: 0.4375 - val_loss: 1.0694 - val_accuracy: 0.3594
# Epoch 5/15
# 4/4 [==============================] - 0s 88ms/step - loss: 0.9151 - accuracy: 0.5000 - val_loss: 1.0351 - val_accuracy: 0.5156
# Epoch 6/15
# 4/4 [==============================] - 0s 88ms/step - loss: 0.8702 - accuracy: 0.7344 - val_loss: 1.0002 - val_accuracy: 0.5000
# Epoch 7/15
# 4/4 [==============================] - 0s 88ms/step - loss: 0.7965 - accuracy: 0.7188 - val_loss: 0.9909 - val_accuracy: 0.5625
# Epoch 8/15
# 4/4 [==============================] - 0s 88ms/step - loss: 0.7213 - accuracy: 0.7656 - val_loss: 0.9232 - val_accuracy: 0.5781
# Epoch 9/15
# 4/4 [==============================] - 0s 88ms/step - loss: 0.6342 - accuracy: 0.7969 - val_loss: 0.9531 - val_accuracy: 0.5312
# Epoch 10/15
# 4/4 [==============================] - 0s 88ms/step - loss: 0.5314 - accuracy: 0.9062 - val_loss: 0.8751 - val_accuracy: 0.6250
# Epoch 11/15
# 4/4 [==============================] - 0s 88ms/step - loss: 0.4420 - accuracy: 0.9062 - val_loss: 0.8383 - val_accuracy: 0.6719
# Epoch 12/15
# 4/4 [==============================] - 0s 89ms/step - loss: 0.4026 - accuracy: 0.9062 - val_loss: 0.7954 - val_accuracy: 0.6875
# Epoch 13/15
# 4/4 [==============================] - 0s 89ms/step - loss: 0.3693 - accuracy: 0.9062 - val_loss: 0.7546 - val_accuracy: 0.7031
# Epoch 14/15
# 4/4 [==============================] - 0s 88ms/step - loss: 0.3620 - accuracy: 0.9062 - val_loss: 0.8099 - val_accuracy: 0.6719
# Epoch 15/15
# 4/4 [==============================] - 0s 88ms/step - loss: 0.2139 - accuracy: 0.9844 - val_loss: 0.8386 - val_accuracy: 0.5938

# %%
loss, accuracy = model.evaluate(X_train,y_train, verbose=False,batch_size=16)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test,y_test, verbose=False,batch_size=16)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Training Accuracy: 0.9688
# Testing Accuracy:  0.5938

# %%
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# # Modelo 3 ResNet152V2 Red neuronal convolucional entrenada [4]

# %%
##### Se específica el nombre del modelo "ResNet152V2".
name = "ResNet152V2"

# Se carga el modelo ResNet152V2 preentrenado, estableciendo sus pesos y excluyendo su capa de clasificación final.
base_model = ResNet152V2(include_top=False, input_shape=(512,512,3), weights='imagenet')
base_model.trainable = False

#Se crea un modelo secuencial con el modelo base ResNet152V2, una capa de agrupación promedio global, dos capas completamente conectadas y una capa de clasificación softmax final.
resnet152V2 = Sequential([
    base_model,
    GAP(),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(3, activation='softmax')
], name=name)

# Se compila el modelo con entropía cruzada categórica dispersa como función de pérdida, optimizador de Adam y precisión como métrica de evaluación.
resnet152V2.compile(
    loss='CategoricalCrossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Se configuran las devoluciones de llamada EarlyStopping y ModelCheckpoint para monitorear el proceso de capacitación y guardar los mejores pesos de modelo.
cbs = [
    EarlyStopping(patience=3, restore_best_weights=True),
    ModelCheckpoint(name + ".h5", save_best_only=True)
]

# Se entrena el modelo usando los conjuntos de datos de entrenamiento y validación, usando 15 épocas y las devoluciones de llamadas definidas previamente.
history = resnet152V2.fit(
    X_train, y_train,
    epochs = 15,
    validation_data=(X_test, y_test),
    verbose=1,
    batch_size=32,
    callbacks=cbs
)
# Out:
# Epoch 1/15
# 2/2 [==============================] - 8s 5s/step - loss: 0.9638 - accuracy: 0.5469 - val_loss: 0.4706 - val_accuracy: 0.9375
# Epoch 2/15
# 2/2 [==============================] - 4s 4s/step - loss: 0.3096 - accuracy: 0.9844 - val_loss: 0.1636 - val_accuracy: 1.0000
# Epoch 3/15
# 2/2 [==============================] - 4s 4s/step - loss: 0.0971 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 1.0000
# Epoch 4/15
# 2/2 [==============================] - 5s 4s/step - loss: 0.0423 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 1.0000
# Epoch 5/15
# 2/2 [==============================] - 6s 5s/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.0319 - val_accuracy: 1.0000
# Epoch 6/15
# 2/2 [==============================] - 4s 4s/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 7/15
# 2/2 [==============================] - 6s 6s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 8/15
# 2/2 [==============================] - 4s 4s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 9/15
# 2/2 [==============================] - 4s 4s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 10/15
# 2/2 [==============================] - 5s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 11/15
# 2/2 [==============================] - 4s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 12/15
# 2/2 [==============================] - 5s 5s/step - loss: 8.2379e-04 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 13/15
# 2/2 [==============================] - 6s 5s/step - loss: 9.0213e-04 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 14/15
# 2/2 [==============================] - 4s 4s/step - loss: 4.5832e-04 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 15/15
# 2/2 [==============================] - 6s 5s/step - loss: 7.5367e-04 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000

# %%
#resnet152V2.summary()

# %%
tf.keras.utils.plot_model(resnet152V2, 'model.png', show_shapes=True) #pip install pydot

# %%
loss, accuracy = resnet152V2.evaluate(X_train,y_train, verbose=False) #batch_size=32
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = resnet152V2.evaluate(X_test,y_test, verbose=False)#batch_size=32
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Training Accuracy: 1.0000
# Testing Accuracy:  1.0000

# %%
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
# Se establece la ruta del archivo al modelo pre-entrenado
model_file_path = '/content/ResNet152V2.h5'

# Se carga el modelo pre-entrenado
loaded_model = load_model(model_file_path)

#Imprimero el resumen del modelo ResNet152V2.h5 para clasificación de gatitos,perritos y animales salvajes
loaded_model.summary()
# Out:
# Model: "ResNet152V2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152v2 (Functional)    (None, 16, 16, 2048)      58331648
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_7 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 58,856,963
# Trainable params: 525,315
# Non-trainable params: 58,331,648
# _________________________________________________________________

# %%
#!nvidia-smi --help

# %%
#!nvidia-smi -q -g 0 -d UTILIZATION -l 1
# !nvidia-smi
#!nvidia-smi --help
# Out:
# Tue Aug 15 11:57:20 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3070        Off | 00000000:01:00.0 Off |                  N/A |
# | 64%   53C    P2             175W / 270W |   7520MiB /  8192MiB |     37%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    913590      C   /usr/bin/python3                           7514MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Referencias
#
# [1] Choi, Y., Uh, Y., Yoo, J., & Ha, J.-W. (2020). StarGAN v2: Diverse Image Synthesis for Multiple Domains. Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition.
#
# [2] Diederik P. Kingma, & Jimmy Ba. (2017). Adam: A Method for Stochastic Optimization.
#
# [3] https://docs.nvidia.com/deeplearning/frameworks/tensorflow-release-notes/rel_22-06.html
#
# [4] Kaiming He, Xiangyu Zhang, Shaoqing Ren, & Jian Sun. (2016). Identity Mappings in Deep Residual Networks.
